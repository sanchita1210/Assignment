# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SANCHITA WADHWANI**

# %% [markdown]
# Real Estate Data Analyst

# %% [markdown]
# *Data scientists help improve how humans make decisions and how algorithms optimize outcomes.*

# %% [markdown]
# ### This program adds two numbers.

# %%
1 + 1
# Out:
# 2

# %%
2 + 2
# Out:
# 4

# %%
3 + 3
# Out:
# 6

# %% [markdown]
# Hello and bye...
#
# ---

# %% [markdown]
# * Skills

# %% [markdown]
# 1) Tablue
# 2) Altryx
# 3) Python

# %% [markdown]
# | Class | Percentage | School |
# |---|---|---|
# | 10th | 88% | St Joseph |
# | 12Th | 92% | Emerald Heights |

# %% [markdown]
# ##### The End.
